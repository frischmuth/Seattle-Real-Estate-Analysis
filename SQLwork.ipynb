# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
conn = psycopg2.connect(dbname='seattle_housing', user = 'postgres', host='localhost')

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
value_histories = pd.read_csv('data/value_histories/EXTR_ValueHistory_V.csv', nrows=10000)

# %%
value_histories.head(0)
# Out:
# Empty DataFrame
# Columns: [Major, Minor, TaxYr, OmitYr, ApprLandVal, ApprImpsVal, ApprImpIncr, LandVal, ImpsVal, TaxValReason, TaxStatus, LevyCode, ChangeDate, ChangeDocId, Reason, SplitCode]
# Index: []

# %%
value_histories['TaxValReason'].count()
# Out:
# 10000

# %%
value_histories[value_histories['Reason']=='NEW PLAT']
# Out:
#        Major  Minor  TaxYr  OmitYr  ApprLandVal  ApprImpsVal  ApprImpIncr  \
# 54    386510     30   2003       0            0            0            0
# 452   721265    990   1992       0            0            0            0
# 960   211101    890   2003       0            0            0            0
# 1587  253750    140   1995       0            0            0            0
# 1857  675260    850   1995       0            0            0            0
# 1909  189890     40   1998       0            0            0            0
# 2001  382760     90   1993       0            0            0            0
# 2098  339546     20   1990       0            0            0            0
# 2176  689140    360   2016       0            0            0            0
# 2220  383206   1040   2008       0            0            0            0
# 2470  542350     90   1984       0            0            0            0
# 2497  719780    170   2002       0            0            0            0
# ...

# %%
value_histories[value_histories['Major']==413800].sort_values('TaxYr')
# Out:
#        Major  Minor  TaxYr  OmitYr  ApprLandVal  ApprImpsVal  ApprImpIncr  \
# 4837  413800    340   2016       0            0            0            0
# 4838  413800    340   2016       0        96000            0        96000
# 4839  413800    340   2017       0        96000            0            0
# 4840  413800    340   2018       0            0            0            0
# 4841  413800    340   2018       0        96000            0            0
# 4842  413800    340   2018       0        96000       354000       329000
# 4843  413800    340   2019       0       115000       437000            0
# 4844  413800    340   2020       0       115000       449000            0
#
#       LandVal  ImpsVal TaxValReason TaxStatus  LevyCode           ChangeDate  \
# 4837        0        0                      T       120  2014-10-20 00:00:00
# 4838    96000        0                      T       120  2015-09-08 00:00:00
# ...

# %%
value_histories['Reason'].unique()
# Out:
# array(['REVALUE', 'MAINTENANCE', 'EXTENSION', 'LEVY CODE CHNG',
#        'NEW PLAT', 'SEGREGATION', 'JULY BOARD ORDER', 'CORRECTION BOARD',
#        'STATE BOARD ORDER', 'LEGAL CHANGE', 'OMITTED ASSMT',
#        'S.C. FROZEN VALUE', 'SR CIT CHANGE', 'MERGER',
#        'HOME IMP EXEMPTION', 'TAX STATUS CHNG', 'AMENDMENT',
#        'BOARD EXTENSION', 'MOBILE HOME X-FER', 'MAINT', 'NOV BOARD ORDER',
#        'DESTROYED PROPERTY', 'CORRECTION', 'OPEN SPACE',
#        'JUNE BOARD ORDER', 'KILL BY MERGE', 'HOME IMP EXPIRED'],
#       dtype=object)

# %%
alchemyEngine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/seattle_housing', pool_recycle=3600);

postgreSQLConnection = alchemyEngine.connect();

postgreSQLTable = "value_histories";

 

try:

    frame = value_histories.to_sql(postgreSQLTable, postgreSQLConnection, if_exists='fail', index=False);

except ValueError as vx:

    print(vx)

except Exception as ex:  

    print(ex)

else:

    print("PostgreSQL Table {postgreSQLTable} has been created successfully.");

finally:

    postgreSQLConnection.close();
# Out:
# PostgreSQL Table {postgreSQLTable} has been created successfully.

# %%
for filename in os.listdir('/Users/ross/Galvanize/Seattle-Real-Estate-Analysis/data/csv_to_sql'):
    filename = filename.split('.')[0]
    if filename[:5]=='EXTR_':
        filename = filename[5:]
    print(filename)
# Out:
# TaxAcctReceivable_V
# Parcels_for_King_County_with_Address_with_Property_Information__parcel_address_area
# ValueHistory_V
# Building_Permits
# Parcel
# ChangeHistDetail_V
# zip_files
# Capacity_For_All_Parcels_2015
# Land_Use_Permits
# UnitBreakdown
# ResBldg

# %%
a = 5
print(f"Tommy is {b}",b=6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-09d1743bb418> in <module>
#       1 a = 5
# ----> 2 print(f"Tommy is {b}",b=6)
#
# NameError: name 'b' is not defined
